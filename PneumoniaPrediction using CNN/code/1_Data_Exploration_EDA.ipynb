# %% [markdown]
# # Part 1 - Data Collection and EDA

# %% [markdown]
# This notebook will focus on exploring data, analyzing an plotting insightful stats (class balance, image size distribution, etc.), loading data as 3-dimensional array, and preprocess data to prepare for modeling.

# %% [markdown]
# ### Imports

# %%
# Import libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

import os
from glob import glob
import cv2
import skimage
from skimage.transform import resize
from PIL import Image
import h5py
import glob

# %% [markdown]
# ### Load the data

# %%
# Define train and test directories
train_dir = r'D:\Class\Notes\Sem 6th\pneumonia_detection_CNN-master\data\chest_xray\train'
test_dir = r'D:\Class\Notes\Sem 6th\pneumonia_detection_CNN-master\data\chest_xray\test'

# %%
# Bacterial Pneumonia images
# glob class is to iterate all jpeg images in the directory and make a list of all image paths
b_images = glob.glob(train_dir + '/bacteria/*.jpeg')

# %%
# Viral pneumonia images
v_images = glob.glob(train_dir + '/viral/*.jpeg')

# %%
# Normal images
n_images = glob.glob(train_dir + '/normal/*.jpeg')

# %% [markdown]
# ### EDA

# %% [markdown]
# Let's create a bar plot for distribution of all three classes in train dataset.

# %%
# Debugging: Print lengths to ensure data is present
print(f'Number of Normal images: {len(n_images)}')
print(f'Number of Bacterial Pneumonia images: {len(b_images)}')
print(f'Number of Viral Pneumonia images: {len(v_images)}')
# Out:
# Number of Normal images: 1341
# Number of Bacterial Pneumonia images: 2530
# Number of Viral Pneumonia images: 1345

# %%
# Plot the class distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=['Normal', 'Bacterial Pneumonia', 'Viral Pneumonia'],
            y=[len(n_images), len(b_images), len(v_images)])
plt.title('Class Distribution Of Training Dataset')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.show()

# %%
bacterial_images = glob.glob(test_dir + '/bacteria/*.jpeg')
viral_images = glob.glob(test_dir + '/viral/*.jpeg')
normal_images = glob.glob(test_dir + '/normal/*.jpeg')

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=['Normal', 'Bacterial Pneumonia', 'Viral Pneumonia'],
            y=[len(normal_images), len(bacterial_images), len(viral_images)])
plt.title('Class Distribution Of Testing Dataset')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.show()

# %% [markdown]
# This is obviously an unbalanced dataset, weighted to the chest X-rays with bacterial pneumonia. Considering bacterial pneumonia is the more severe than viral pneumonia, it is fine that our model learn about the specifics of bacterial pneumonia the most.

# %%
# Convert the first pneumonia image to array of pixels
np.asarray(plt.imread(b_images[0]))
# Out:
# array([[19, 19, 18, ...,  1,  0,  0],
#        [19, 19, 18, ...,  1,  0,  0],
#        [19, 19, 18, ...,  1,  0,  0],
#        ...,
#        [10, 10, 10, ..., 15, 15, 15],
#        [10, 10, 10, ..., 15, 15, 15],
#        [10, 10, 10, ..., 15, 15, 15]], dtype=uint8)

# %%
# Convert the first normal image to array of pixels
np.asarray(plt.imread(n_images[0]))
# Out:
# array([[ 22,  24,  24, ...,  96,  94,  93],
#        [ 23,  24,  24, ...,  97,  94,  92],
#        [ 24,  24,  23, ...,  99,  96,  94],
#        ...,
#        [ 49,  50,  48, ..., 119, 119, 119],
#        [ 50,  52,  53, ..., 123, 124, 123],
#        [ 52,  53,  54, ..., 129, 128, 127]], dtype=uint8)

# %%
# Check the shape of first pneumonia image array
np.asarray(plt.imread(b_images[0])).shape
# Out:
# (760, 1152)

# %%
# Check the shape of first normal image array
np.asarray(plt.imread(n_images[0])).shape
# Out:
# (1858, 2090)

# %% [markdown]
# It seems like image size is not uniform across the dataset and also too large to train a neural network in terms of time complexity. Let's also plot the image size distribution of train dataset to determine what would be the ideal height/width to downsize them

# %%
train_images = b_images + n_images + v_images

# %%
img_class = []
height = []
weight = []

# Iterate through each image path
for d in os.listdir(train_dir):
        # find height and width of all train images
        for image in train_images:
                img_class.append(d)
                img_array = np.array(Image.open(image))
                height.append(img_array.shape[0])
                weight.append(img_array.shape[1])


# save image sizes to data frame
size_df = pd.DataFrame({
    'class': img_class,
    'height': height,
    'width': weight
})

# %%
plt.figure(figsize = (10, 6))

sns.kdeplot(
    size_df['height'], label='Height (px)')
sns.kdeplot(
    size_df['width'], label='Width (px)')

plt.xlabel('Pixels')
plt.ylabel('Frequency')
plt.title('Image Size Distribution')
# Out:
# Text(0.5, 1.0, 'Image Size Distribution')

# %% [markdown]
# Most images were at least 224 × 224 pixels and contained RGB color channels. Images that were smaller than
# 224 x 224 pixels or in greyscale should be removed from analysis. This was done after getting poor results with preprocessed images to smaller size and grayscale mode even though it gives faster results.

# %% [markdown]
# Let's plot some images to see the variations in terms of angle, zooming, opaqueness, etc. We know that the dataset was already cleaned up medical proffesionals for usability. However, plotting would guide us to determine the scale of data preprocessing and augmentation process.

# %%
# Plot first four bacterial pneumonia images
fig=plt.figure(figsize=(16, 4))
plt.title('Bacterial Pneumonia Images', fontsize=18)
cols = 4
rows = 1
for i in range(1, cols*rows +1):
    img = np.asarray(plt.imread(b_images[i]))
    fig.add_subplot(rows, cols, i)
    plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
# Plot first four bacterial pneumonia images
fig=plt.figure(figsize=(16, 4))
plt.title('Viral Pneumonia Images', fontsize=18)
cols = 4
rows = 1
for i in range(1, cols*rows +1):
    img = np.asarray(plt.imread(v_images[i]))
    fig.add_subplot(rows, cols, i)
    plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
# Plot first four normal images
fig=plt.figure(figsize=(16, 4))
plt.title('Healthy Images', fontsize=18)
cols = 4
rows = 1
for i in range(1, cols*rows +1):
    img = np.asarray(plt.imread(n_images[i]))
    fig.add_subplot(rows, cols, i)
    plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
# Define a function to plot bacterial, viral, and normal images side by side

def pair_plot(index, img1_list, img2_list, img3_list):
    image1 = skimage.transform.resize(cv2.imread(img1_list[index]), (224, 224, 3))
    image2 = skimage.transform.resize(cv2.imread(img2_list[index]), (224, 224, 3))
    image3 = skimage.transform.resize(cv2.imread(img3_list[index]), (224, 224, 3))
    pair = np.concatenate((image1, image2, image3), axis=1)
    plt.figure(figsize=(10,8))
    plt.title("Bacterial Pneumonia vs Viral Pneumonia vs Normal")    
    plt.imshow(pair)
    plt.show()
    
for x in range(5):
    pair_plot(x, b_images, v_images, n_images)

# %% [markdown]
# Pneumonia positive images seems to be more faint as the borders between organs are less sharp because of the soft tissue (water) in the lungs.
# Black: Air
# Dark Grey: Fat
# Light Grey: Soft tissue
# Off white: Bone
# Bright white: Metal

# %%
THRESHOLD

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model
import os

# Load the model
model = load_model(r'D:\Class\Notes\Sem 6th\pneumonia_detection_CNN-master\flask\static\model84.hdf5')

# Initialize ImageDataGenerator for test data
test_datagen = ImageDataGenerator(rescale=1./255)  # Normalize the images

# Define the test directory
test_dir = r'D:\Class\Notes\Sem 6th\pneumonia_detection_CNN-master\data\chest_xray\test'

# Create a test generator
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(150, 150),
    batch_size=1,
    class_mode=None,  # No labels required for prediction
    shuffle=False  # Important to keep order for later evaluation
)

# Predict on the test data
predictions = model.predict(test_generator, steps=len(test_generator), verbose=1)

# Define a threshold for classification
threshold = 0.7

# Apply threshold to predictions
predicted_classes = np.argmax(predictions, axis=1)  # Get class indices with highest probability
predicted_probabilities = np.max(predictions, axis=1)  # Get the probabilities of the highest class

# Apply threshold to classify
binary_predictions = (predicted_probabilities > threshold).astype(int)

# Print results
for filename, pred_class, prob in zip(test_generator.filenames, predicted_classes, predicted_probabilities):
    print(f"Filename: {filename},  Probability: {prob:.2f}, Above Threshold: {binary_predictions[test_generator.filenames.index(filename)]}")
# Out:
# Found 624 images belonging to 3 classes.
# 624/624 [==============================] - 18s 29ms/step
# Filename: bacteria\person100_bacteria_475.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: bacteria\person100_bacteria_477.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person100_bacteria_478.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person100_bacteria_479.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person100_bacteria_480.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person100_bacteria_481.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person100_bacteria_482.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person101_bacteria_483.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person101_bacteria_484.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person101_bacteria_485.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person101_bacteria_486.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person102_bacteria_487.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person103_bacteria_488.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person103_bacteria_489.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person103_bacteria_490.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person104_bacteria_491.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person104_bacteria_492.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person108_bacteria_504.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: bacteria\person108_bacteria_506.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person108_bacteria_507.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person108_bacteria_511.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: bacteria\person109_bacteria_512.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: bacteria\person109_bacteria_513.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person109_bacteria_517.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: bacteria\person109_bacteria_519.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person109_bacteria_522.jpeg,  Probability: 0.67, Above Threshold: 0
# Filename: bacteria\person109_bacteria_523.jpeg,  Probability: 0.70, Above Threshold: 1
# Filename: bacteria\person109_bacteria_526.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person109_bacteria_527.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person109_bacteria_528.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person110_bacteria_531.jpeg,  Probability: 0.79, Above Threshold: 1
# Filename: bacteria\person111_bacteria_533.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person111_bacteria_534.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person111_bacteria_535.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person111_bacteria_536.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person111_bacteria_537.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person112_bacteria_538.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person112_bacteria_539.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person113_bacteria_540.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person113_bacteria_541.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person113_bacteria_542.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person113_bacteria_543.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person114_bacteria_544.jpeg,  Probability: 0.61, Above Threshold: 0
# Filename: bacteria\person114_bacteria_545.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: bacteria\person114_bacteria_546.jpeg,  Probability: 0.87, Above Threshold: 1
# Filename: bacteria\person117_bacteria_553.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person117_bacteria_556.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person117_bacteria_557.jpeg,  Probability: 0.67, Above Threshold: 0
# Filename: bacteria\person118_bacteria_559.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: bacteria\person118_bacteria_560.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person119_bacteria_565.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person119_bacteria_566.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: bacteria\person119_bacteria_567.jpeg,  Probability: 0.82, Above Threshold: 1
# Filename: bacteria\person119_bacteria_568.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: bacteria\person120_bacteria_570.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person120_bacteria_571.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: bacteria\person120_bacteria_572.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person120_bacteria_573.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person121_bacteria_575.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: bacteria\person121_bacteria_576.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: bacteria\person121_bacteria_578.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: bacteria\person121_bacteria_579.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person121_bacteria_580.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person122_bacteria_581.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: bacteria\person122_bacteria_582.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person122_bacteria_583.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person122_bacteria_584.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person122_bacteria_585.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person122_bacteria_586.jpeg,  Probability: 0.88, Above Threshold: 1
# Filename: bacteria\person123_bacteria_587.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person124_bacteria_589.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: bacteria\person124_bacteria_590.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: bacteria\person124_bacteria_591.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person124_bacteria_592.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person125_bacteria_594.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person125_bacteria_595.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: bacteria\person126_bacteria_598.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person126_bacteria_599.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person126_bacteria_600.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person127_bacteria_602.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person127_bacteria_603.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person127_bacteria_604.jpeg,  Probability: 0.46, Above Threshold: 0
# Filename: bacteria\person128_bacteria_605.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person128_bacteria_606.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: bacteria\person128_bacteria_607.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: bacteria\person128_bacteria_608.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person130_bacteria_623.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person130_bacteria_625.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person130_bacteria_626.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person130_bacteria_627.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person130_bacteria_628.jpeg,  Probability: 0.80, Above Threshold: 1
# Filename: bacteria\person131_bacteria_629.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: bacteria\person132_bacteria_632.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person133_bacteria_633.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: bacteria\person133_bacteria_634.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person133_bacteria_635.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person133_bacteria_637.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person133_bacteria_638.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person134_bacteria_640.jpeg,  Probability: 0.78, Above Threshold: 1
# Filename: bacteria\person134_bacteria_641.jpeg,  Probability: 0.77, Above Threshold: 1
# Filename: bacteria\person134_bacteria_642.jpeg,  Probability: 0.52, Above Threshold: 0
# Filename: bacteria\person134_bacteria_643.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: bacteria\person134_bacteria_644.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: bacteria\person135_bacteria_646.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person135_bacteria_647.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person136_bacteria_648.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person136_bacteria_649.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: bacteria\person136_bacteria_650.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person136_bacteria_652.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person136_bacteria_654.jpeg,  Probability: 0.73, Above Threshold: 1
# Filename: bacteria\person137_bacteria_655.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person138_bacteria_657.jpeg,  Probability: 0.45, Above Threshold: 0
# Filename: bacteria\person138_bacteria_658.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: bacteria\person138_bacteria_659.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person139_bacteria_661.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person139_bacteria_662.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person139_bacteria_663.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person139_bacteria_664.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person139_bacteria_665.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person139_bacteria_666.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person140_bacteria_667.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person140_bacteria_668.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person141_bacteria_670.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person141_bacteria_676.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person141_bacteria_677.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person141_bacteria_678.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person141_bacteria_681.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person142_bacteria_682.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person142_bacteria_683.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person142_bacteria_684.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person143_bacteria_687.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person143_bacteria_688.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person143_bacteria_689.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person144_bacteria_690.jpeg,  Probability: 0.88, Above Threshold: 1
# Filename: bacteria\person145_bacteria_696.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person146_bacteria_700.jpeg,  Probability: 0.84, Above Threshold: 1
# Filename: bacteria\person146_bacteria_703.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person146_bacteria_704.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person147_bacteria_705.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person147_bacteria_706.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person147_bacteria_707.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person147_bacteria_711.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person149_bacteria_713.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person150_bacteria_715.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person150_bacteria_716.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person150_bacteria_717.jpeg,  Probability: 0.73, Above Threshold: 1
# Filename: bacteria\person151_bacteria_718.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person152_bacteria_720.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person152_bacteria_721.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person152_bacteria_722.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person152_bacteria_723.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person152_bacteria_724.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: bacteria\person153_bacteria_725.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: bacteria\person153_bacteria_726.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: bacteria\person154_bacteria_728.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person155_bacteria_729.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person155_bacteria_730.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person155_bacteria_731.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: bacteria\person157_bacteria_735.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person157_bacteria_739.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person157_bacteria_740.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person158_bacteria_742.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: bacteria\person158_bacteria_743.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: bacteria\person158_bacteria_744.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person158_bacteria_745.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person159_bacteria_746.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person159_bacteria_747.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person161_bacteria_757.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person161_bacteria_759.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person161_bacteria_762.jpeg,  Probability: 0.51, Above Threshold: 0
# Filename: bacteria\person171_bacteria_826.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person172_bacteria_827.jpeg,  Probability: 0.60, Above Threshold: 0
# Filename: bacteria\person172_bacteria_828.jpeg,  Probability: 0.79, Above Threshold: 1
# Filename: bacteria\person173_bacteria_829.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person173_bacteria_830.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person173_bacteria_831.jpeg,  Probability: 0.81, Above Threshold: 1
# Filename: bacteria\person174_bacteria_832.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person175_bacteria_833.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person175_bacteria_834.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person175_bacteria_835.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person78_bacteria_378.jpeg,  Probability: 0.74, Above Threshold: 1
# Filename: bacteria\person78_bacteria_380.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person78_bacteria_381.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person78_bacteria_382.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person78_bacteria_384.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person78_bacteria_385.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person78_bacteria_386.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person78_bacteria_387.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person80_bacteria_389.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person80_bacteria_390.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person80_bacteria_391.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person80_bacteria_392.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person80_bacteria_393.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person81_bacteria_395.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person81_bacteria_396.jpeg,  Probability: 0.84, Above Threshold: 1
# Filename: bacteria\person81_bacteria_397.jpeg,  Probability: 0.63, Above Threshold: 0
# Filename: bacteria\person81_bacteria_398.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person82_bacteria_402.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person82_bacteria_403.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person82_bacteria_404.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person82_bacteria_405.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person83_bacteria_407.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person83_bacteria_409.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person83_bacteria_410.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person83_bacteria_411.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person83_bacteria_412.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person83_bacteria_414.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person85_bacteria_417.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person85_bacteria_419.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person85_bacteria_421.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person85_bacteria_422.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: bacteria\person85_bacteria_423.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person85_bacteria_424.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person86_bacteria_428.jpeg,  Probability: 0.67, Above Threshold: 0
# Filename: bacteria\person86_bacteria_429.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person87_bacteria_433.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person87_bacteria_434.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person88_bacteria_437.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: bacteria\person88_bacteria_438.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person88_bacteria_439.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: bacteria\person89_bacteria_440.jpeg,  Probability: 0.76, Above Threshold: 1
# Filename: bacteria\person90_bacteria_442.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person90_bacteria_443.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: bacteria\person91_bacteria_445.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person91_bacteria_446.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person91_bacteria_447.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person91_bacteria_448.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person91_bacteria_449.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: bacteria\person92_bacteria_450.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person92_bacteria_451.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: bacteria\person93_bacteria_453.jpeg,  Probability: 0.83, Above Threshold: 1
# Filename: bacteria\person93_bacteria_454.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: bacteria\person94_bacteria_456.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person94_bacteria_457.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person94_bacteria_458.jpeg,  Probability: 0.66, Above Threshold: 0
# Filename: bacteria\person95_bacteria_463.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person96_bacteria_464.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person96_bacteria_465.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: bacteria\person96_bacteria_466.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: bacteria\person97_bacteria_468.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: bacteria\person99_bacteria_473.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: bacteria\person99_bacteria_474.jpeg,  Probability: 0.85, Above Threshold: 1
# Filename: normal\IM-0001-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0003-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0005-0001.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: normal\IM-0006-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0007-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0009-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0010-0001.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: normal\IM-0011-0001-0001.jpeg,  Probability: 0.48, Above Threshold: 0
# Filename: normal\IM-0011-0001-0002.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0011-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0013-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0015-0001.jpeg,  Probability: 0.70, Above Threshold: 1
# Filename: normal\IM-0016-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0017-0001.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: normal\IM-0019-0001.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: normal\IM-0021-0001.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: normal\IM-0022-0001.jpeg,  Probability: 0.88, Above Threshold: 1
# Filename: normal\IM-0023-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0025-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0027-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0028-0001.jpeg,  Probability: 0.51, Above Threshold: 0
# Filename: normal\IM-0029-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0030-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0031-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0033-0001-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0033-0001-0002.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0033-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\IM-0035-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0036-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0037-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0039-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0041-0001.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: normal\IM-0043-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0045-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0046-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0049-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0050-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0059-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0061-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0063-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0065-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0067-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0069-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0070-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0071-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0073-0001.jpeg,  Probability: 0.67, Above Threshold: 0
# Filename: normal\IM-0075-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0077-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0079-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0081-0001.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: normal\IM-0083-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0084-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0085-0001.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: normal\IM-0086-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0087-0001.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: normal\IM-0089-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0091-0001.jpeg,  Probability: 0.74, Above Threshold: 1
# Filename: normal\IM-0093-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0095-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0097-0001.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: normal\IM-0099-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0101-0001.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: normal\IM-0102-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\IM-0103-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0105-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0107-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\IM-0109-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\IM-0110-0001.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: normal\IM-0111-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0007-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0012-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0013-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0019-0001.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0023-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0027-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0028-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0029-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0030-0001.jpeg,  Probability: 0.71, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0033-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0035-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0041-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0045-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0051-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0052-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0058-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0059-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0060-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0066-0001.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0072-0001.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0073-0001.jpeg,  Probability: 0.54, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0079-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0081-0001.jpeg,  Probability: 0.51, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0086-0001.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0092-0001.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0095-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0096-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0098-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0102-0001.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0105-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0107-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0110-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0111-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0112-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0117-0001.jpeg,  Probability: 0.87, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0120-0001.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0123-0001.jpeg,  Probability: 0.88, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0129-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0130-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0131-0001.jpeg,  Probability: 0.85, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0132-0001.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0135-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0139-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0141-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0145-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0146-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0150-0001.jpeg,  Probability: 0.62, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0171-0001.jpeg,  Probability: 0.50, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0173-0001-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0173-0001-0002.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0195-0001.jpeg,  Probability: 0.80, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0196-0001.jpeg,  Probability: 0.58, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0198-0001.jpeg,  Probability: 0.69, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0199-0001.jpeg,  Probability: 0.79, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0201-0001.jpeg,  Probability: 0.83, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0206-0001.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0207-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0210-0001.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0213-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0217-0001.jpeg,  Probability: 0.56, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0219-0001.jpeg,  Probability: 0.84, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0221-0001.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0222-0001.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0229-0001.jpeg,  Probability: 0.79, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0232-0001.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0233-0001.jpeg,  Probability: 0.87, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0237-0001.jpeg,  Probability: 0.87, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0238-0001.jpeg,  Probability: 0.78, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0241-0001.jpeg,  Probability: 0.56, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0246-0001-0001.jpeg,  Probability: 0.78, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0246-0001-0002.jpeg,  Probability: 0.78, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0246-0001.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0249-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0251-0001.jpeg,  Probability: 0.50, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0252-0001.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0256-0001.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0259-0001.jpeg,  Probability: 0.79, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0267-0001.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0271-0001.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0272-0001.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0273-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0274-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0275-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0276-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0277-0001.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0278-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0279-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0280-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0281-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0282-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0283-0001.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0285-0001.jpeg,  Probability: 0.47, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0286-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0287-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0288-0001.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0289-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0290-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0292-0001.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0294-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0297-0001.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0300-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0301-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0302-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0303-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0304-0001.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0305-0001.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0307-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0309-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0310-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0311-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0312-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0313-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0315-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0316-0001.jpeg,  Probability: 0.47, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0317-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0319-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0321-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0322-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0323-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0325-0001.jpeg,  Probability: 0.55, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0326-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0327-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0328-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0329-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0330-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0331-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0332-0001.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0333-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0335-0001.jpeg,  Probability: 0.76, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0336-0001.jpeg,  Probability: 0.83, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0337-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0338-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0339-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0340-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0341-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0343-0001.jpeg,  Probability: 0.84, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0345-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0346-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0347-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0348-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0349-0001.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0350-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0351-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0352-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0353-0001.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0354-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0357-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0359-0001.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0360-0001.jpeg,  Probability: 0.66, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0361-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0362-0001.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0364-0001.jpeg,  Probability: 0.52, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0366-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0368-0001.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0369-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0370-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0372-0001.jpeg,  Probability: 1.00, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0373-0001.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0374-0001-0001.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0374-0001-0002.jpeg,  Probability: 0.66, Above Threshold: 0
# Filename: normal\NORMAL2-IM-0374-0001.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0376-0001.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0378-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0380-0001.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: normal\NORMAL2-IM-0381-0001.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: viral\person10_virus_35.jpeg,  Probability: 0.65, Above Threshold: 0
# Filename: viral\person11_virus_38.jpeg,  Probability: 0.79, Above Threshold: 1
# Filename: viral\person14_virus_44.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: viral\person15_virus_46.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: viral\person1608_virus_2786.jpeg,  Probability: 0.72, Above Threshold: 1
# Filename: viral\person1610_virus_2793.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: viral\person1612_virus_2797.jpeg,  Probability: 0.76, Above Threshold: 1
# Filename: viral\person1612_virus_2798.jpeg,  Probability: 0.59, Above Threshold: 0
# Filename: viral\person1613_virus_2799.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: viral\person1614_virus_2800.jpeg,  Probability: 0.82, Above Threshold: 1
# Filename: viral\person1615_virus_2801.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: viral\person1616_virus_2802.jpeg,  Probability: 0.77, Above Threshold: 1
# Filename: viral\person1618_virus_2805.jpeg,  Probability: 0.81, Above Threshold: 1
# Filename: viral\person1619_virus_2806.jpeg,  Probability: 0.99, Above Threshold: 1
# Filename: viral\person1620_virus_2807.jpeg,  Probability: 0.98, Above Threshold: 1
# Filename: viral\person1622_virus_2810.jpeg,  Probability: 0.59, Above Threshold: 0
# Filename: viral\person1623_virus_2813.jpeg,  Probability: 0.87, Above Threshold: 1
# Filename: viral\person1625_virus_2817.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: viral\person1626_virus_2818.jpeg,  Probability: 0.80, Above Threshold: 1
# Filename: viral\person1627_virus_2819.jpeg,  Probability: 0.50, Above Threshold: 0
# Filename: viral\person1628_virus_2821.jpeg,  Probability: 0.74, Above Threshold: 1
# Filename: viral\person1628_virus_2822.jpeg,  Probability: 0.87, Above Threshold: 1
# Filename: viral\person1629_virus_2823.jpeg,  Probability: 0.65, Above Threshold: 0
# Filename: viral\person1631_virus_2826.jpeg,  Probability: 0.65, Above Threshold: 0
# Filename: viral\person1632_virus_2827.jpeg,  Probability: 0.51, Above Threshold: 0
# Filename: viral\person1633_virus_2829.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: viral\person1634_virus_2830.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: viral\person1635_virus_2831.jpeg,  Probability: 0.62, Above Threshold: 0
# Filename: viral\person1637_virus_2834.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: viral\person1640_virus_2839.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: viral\person1641_virus_2840.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: viral\person1642_virus_2842.jpeg,  Probability: 0.75, Above Threshold: 1
# Filename: viral\person1643_virus_2843.jpeg,  Probability: 0.67, Above Threshold: 0
# Filename: viral\person1644_virus_2844.jpeg,  Probability: 0.87, Above Threshold: 1
# Filename: viral\person1645_virus_2845.jpeg,  Probability: 0.67, Above Threshold: 0
# Filename: viral\person1647_virus_2848.jpeg,  Probability: 0.82, Above Threshold: 1
# Filename: viral\person1649_virus_2850.jpeg,  Probability: 0.71, Above Threshold: 1
# Filename: viral\person1650_virus_2852.jpeg,  Probability: 0.53, Above Threshold: 0
# Filename: viral\person1650_virus_2854.jpeg,  Probability: 0.70, Above Threshold: 1
# Filename: viral\person1651_virus_2855.jpeg,  Probability: 0.79, Above Threshold: 1
# Filename: viral\person1653_virus_2858.jpeg,  Probability: 0.67, Above Threshold: 0
# Filename: viral\person1653_virus_2859.jpeg,  Probability: 0.80, Above Threshold: 1
# Filename: viral\person1655_virus_2861.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: viral\person1656_virus_2862.jpeg,  Probability: 0.76, Above Threshold: 1
# Filename: viral\person1657_virus_2864.jpeg,  Probability: 0.69, Above Threshold: 0
# Filename: viral\person1659_virus_2867.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: viral\person1660_virus_2869.jpeg,  Probability: 0.56, Above Threshold: 0
# Filename: viral\person1661_virus_2872.jpeg,  Probability: 0.76, Above Threshold: 1
# Filename: viral\person1661_virus_2873.jpeg,  Probability: 0.76, Above Threshold: 1
# Filename: viral\person1662_virus_2875.jpeg,  Probability: 0.64, Above Threshold: 0
# Filename: viral\person1663_virus_2876.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: viral\person1664_virus_2877.jpeg,  Probability: 0.65, Above Threshold: 0
# Filename: viral\person1665_virus_2878.jpeg,  Probability: 0.88, Above Threshold: 1
# Filename: viral\person1667_virus_2881.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: viral\person1668_virus_2882.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: viral\person1669_virus_2884.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: viral\person1669_virus_2885.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: viral\person1670_virus_2886.jpeg,  Probability: 0.77, Above Threshold: 1
# Filename: viral\person1671_virus_2887.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: viral\person1672_virus_2888.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: viral\person1673_virus_2889.jpeg,  Probability: 0.81, Above Threshold: 1
# Filename: viral\person1674_virus_2890.jpeg,  Probability: 0.51, Above Threshold: 0
# Filename: viral\person1675_virus_2891.jpeg,  Probability: 0.81, Above Threshold: 1
# Filename: viral\person1676_virus_2892.jpeg,  Probability: 0.87, Above Threshold: 1
# Filename: viral\person1678_virus_2895.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: viral\person1679_virus_2896.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: viral\person1680_virus_2897.jpeg,  Probability: 0.84, Above Threshold: 1
# Filename: viral\person1682_virus_2899.jpeg,  Probability: 0.70, Above Threshold: 0
# Filename: viral\person1685_virus_2903.jpeg,  Probability: 0.74, Above Threshold: 1
# Filename: viral\person16_virus_47.jpeg,  Probability: 0.80, Above Threshold: 1
# Filename: viral\person17_virus_48.jpeg,  Probability: 0.80, Above Threshold: 1
# Filename: viral\person18_virus_49.jpeg,  Probability: 0.80, Above Threshold: 1
# Filename: viral\person19_virus_50.jpeg,  Probability: 0.71, Above Threshold: 1
# Filename: viral\person1_virus_11.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: viral\person1_virus_12.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: viral\person1_virus_13.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: viral\person1_virus_6.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: viral\person1_virus_7.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: viral\person1_virus_8.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: viral\person1_virus_9.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: viral\person20_virus_51.jpeg,  Probability: 0.87, Above Threshold: 1
# Filename: viral\person21_virus_52.jpeg,  Probability: 0.85, Above Threshold: 1
# Filename: viral\person21_virus_53.jpeg,  Probability: 0.79, Above Threshold: 1
# Filename: viral\person22_virus_54.jpeg,  Probability: 0.82, Above Threshold: 1
# Filename: viral\person22_virus_55.jpeg,  Probability: 0.91, Above Threshold: 1
# Filename: viral\person23_virus_56.jpeg,  Probability: 0.96, Above Threshold: 1
# Filename: viral\person24_virus_58.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: viral\person25_virus_59.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: viral\person26_virus_60.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: viral\person28_virus_62.jpeg,  Probability: 0.66, Above Threshold: 0
# Filename: viral\person28_virus_63.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: viral\person29_virus_64.jpeg,  Probability: 0.63, Above Threshold: 0
# Filename: viral\person30_virus_69.jpeg,  Probability: 0.72, Above Threshold: 1
# Filename: viral\person31_virus_70.jpeg,  Probability: 0.65, Above Threshold: 0
# Filename: viral\person32_virus_71.jpeg,  Probability: 0.52, Above Threshold: 0
# Filename: viral\person33_virus_72.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: viral\person34_virus_76.jpeg,  Probability: 0.64, Above Threshold: 0
# Filename: viral\person35_virus_80.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: viral\person36_virus_81.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: viral\person37_virus_82.jpeg,  Probability: 0.61, Above Threshold: 0
# Filename: viral\person38_virus_83.jpeg,  Probability: 0.63, Above Threshold: 0
# Filename: viral\person38_virus_84.jpeg,  Probability: 0.62, Above Threshold: 0
# Filename: viral\person39_virus_85.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: viral\person3_virus_15.jpeg,  Probability: 0.84, Above Threshold: 1
# Filename: viral\person3_virus_16.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: viral\person3_virus_17.jpeg,  Probability: 0.68, Above Threshold: 0
# Filename: viral\person40_virus_87.jpeg,  Probability: 0.73, Above Threshold: 1
# Filename: viral\person41_virus_88.jpeg,  Probability: 0.84, Above Threshold: 1
# Filename: viral\person42_virus_89.jpeg,  Probability: 0.70, Above Threshold: 1
# Filename: viral\person43_virus_92.jpeg,  Probability: 0.66, Above Threshold: 0
# Filename: viral\person44_virus_93.jpeg,  Probability: 0.84, Above Threshold: 1
# Filename: viral\person44_virus_94.jpeg,  Probability: 0.88, Above Threshold: 1
# Filename: viral\person45_virus_95.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: viral\person46_virus_96.jpeg,  Probability: 0.68, Above Threshold: 0
# Filename: viral\person47_virus_99.jpeg,  Probability: 0.60, Above Threshold: 0
# Filename: viral\person48_virus_100.jpeg,  Probability: 0.79, Above Threshold: 1
# Filename: viral\person49_virus_101.jpeg,  Probability: 0.85, Above Threshold: 1
# Filename: viral\person50_virus_102.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: viral\person51_virus_105.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: viral\person52_virus_106.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: viral\person53_virus_107.jpeg,  Probability: 0.86, Above Threshold: 1
# Filename: viral\person53_virus_108.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: viral\person54_virus_109.jpeg,  Probability: 0.80, Above Threshold: 1
# Filename: viral\person55_virus_110.jpeg,  Probability: 0.92, Above Threshold: 1
# Filename: viral\person56_virus_112.jpeg,  Probability: 0.85, Above Threshold: 1
# Filename: viral\person57_virus_113.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: viral\person59_virus_116.jpeg,  Probability: 0.84, Above Threshold: 1
# Filename: viral\person60_virus_117.jpeg,  Probability: 0.81, Above Threshold: 1
# Filename: viral\person61_virus_118.jpeg,  Probability: 0.68, Above Threshold: 0
# Filename: viral\person62_virus_119.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: viral\person63_virus_121.jpeg,  Probability: 0.89, Above Threshold: 1
# Filename: viral\person64_virus_122.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: viral\person65_virus_123.jpeg,  Probability: 0.95, Above Threshold: 1
# Filename: viral\person66_virus_125.jpeg,  Probability: 0.93, Above Threshold: 1
# Filename: viral\person67_virus_126.jpeg,  Probability: 0.87, Above Threshold: 1
# Filename: viral\person69_virus_129.jpeg,  Probability: 0.57, Above Threshold: 0
# Filename: viral\person70_virus_130.jpeg,  Probability: 0.97, Above Threshold: 1
# Filename: viral\person71_virus_131.jpeg,  Probability: 0.90, Above Threshold: 1
# Filename: viral\person71_virus_132.jpeg,  Probability: 0.88, Above Threshold: 1
# Filename: viral\person72_virus_133.jpeg,  Probability: 0.69, Above Threshold: 0
# Filename: viral\person74_virus_135.jpeg,  Probability: 0.80, Above Threshold: 1
# Filename: viral\person75_virus_136.jpeg,  Probability: 0.94, Above Threshold: 1
# Filename: viral\person76_virus_138.jpeg,  Probability: 0.84, Above Threshold: 1
# Filename: viral\person77_virus_139.jpeg,  Probability: 0.57, Above Threshold: 0
# Filename: viral\person78_virus_140.jpeg,  Probability: 0.79, Above Threshold: 1
# Filename: viral\person79_virus_148.jpeg,  Probability: 0.85, Above Threshold: 1
# Filename: viral\person8_virus_27.jpeg,  Probability: 0.85, Above Threshold: 1
# Filename: viral\person8_virus_28.jpeg,  Probability: 0.97, Above Threshold: 1

# %% [markdown]
# ### Data Preprocessing

# %%
train_images = glob(train_dir+'/bacterial/*.jpeg')+glob(train_dir+'/viral/*.jpeg')+glob(train_dir+'/normal/*.jpeg')

# %%
test_images = glob(test_dir+'/bacterial/*.jpeg')+glob(test_dir+'/viral/*.jpeg')+glob(test_dir+'/normal/*.jpeg')

# %%
# Print folder names (classes)
print(os.listdir(train_dir))
# Out:
# ['bacterial', 'normal', 'viral']

# %%
# Define a function to load the images to (256 X 256 X 3) numpy arrays (tensor)

def load_data(dir_path):
    X = []
    y = []
    
    for dir_name in os.listdir(dir_path):
        if dir_name == 'normal':
            label = 0
        elif dir_name == 'bacterial':
            label = 1
        elif dir_name == 'viral':
            label = 2
     
        image_paths = glob(dir_path + '/' + dir_name + '/*.jpeg')
        for image_file in image_paths:
            image = np.asarray(skimage.transform.resize(cv2.imread(image_file), (256, 256, 3)))
            X.append(image)
            y.append(label)
                    
    X = np.asarray(X)
    y = np.asarray(y)
    return X,y

# %%
# Create train data (input) and target (output) arrays
X_train, y_train = load_data(train_dir)

# %%
# Create test data (input) and target (output) arrays
X_test, y_test = load_data(test_dir)

# %%
# Print size of train images and label arrays
print(f'Train size: {X_train.shape} \n {y_train.shape}')
# Out:
# Train size: (5232, 256, 256, 3)
#  (5232,)

# %%
# Print size of test images and label arrays
print(f'Test size: {X_test.shape} \n {y_test.shape}')
# Out:
# Test size: (624, 256, 256, 3)
#  (624,)

# %%
# Sanity check of first image array
X_train[0]
# Out:
# array([[[0.07058824, 0.07058824, 0.07058824],
#         [0.0754902 , 0.0754902 , 0.0754902 ],
#         [0.10098039, 0.10098039, 0.10098039],
#         ...,
#         [0.02254902, 0.02254902, 0.02254902],
#         [0.00882353, 0.00882353, 0.00882353],
#         [0.        , 0.        , 0.        ]],
#
#        [[0.07058824, 0.07058824, 0.07058824],
#         [0.08314951, 0.08314951, 0.08314951],
#         [0.09705882, 0.09705882, 0.09705882],
#         ...,
#         [0.02647059, 0.02647059, 0.02647059],
#         [0.01269914, 0.01269914, 0.01269914],
#         [0.        , 0.        , 0.        ]],
#
#        [[0.07352941, 0.07352941, 0.07352941],
#         [0.0899663 , 0.0899663 , 0.0899663 ],
#         [0.09411765, 0.09411765, 0.09411765],
#         ...,
#         [0.03039216, 0.03039216, 0.03039216],
#         [0.01666667, 0.01666667, 0.01666667],
#         [0.00294118, 0.00294118, 0.00294118]],
#
#        ...,
#
#        [[0.03921569, 0.03921569, 0.03921569],
#         [0.03529412, 0.03529412, 0.03529412],
#         [0.03529412, 0.03529412, 0.03529412],
#         ...,
#         [0.05882353, 0.05882353, 0.05882353],
#         [0.05882353, 0.05882353, 0.05882353],
#         [0.05882353, 0.05882353, 0.05882353]],
#
#        [[0.03921569, 0.03921569, 0.03921569],
#         [0.03547794, 0.03547794, 0.03547794],
#         [0.03529412, 0.03529412, 0.03529412],
#         ...,
#         [0.05882353, 0.05882353, 0.05882353],
#         [0.05882353, 0.05882353, 0.05882353],
#         [0.05882353, 0.05882353, 0.05882353]],
#
#        [[0.03921569, 0.03921569, 0.03921569],
#         [0.03921569, 0.03921569, 0.03921569],
#         [0.03529412, 0.03529412, 0.03529412],
#         ...,
#         [0.05882353, 0.05882353, 0.05882353],
#         [0.05882353, 0.05882353, 0.05882353],
#         [0.05882353, 0.05882353, 0.05882353]]])

# %%
y_train[0]
# Out:
# 1

# %% [markdown]
# Below code was commented since I decided to proceed with ImageDataGenerator class to resize and modify images on the fly during trainnig my model. It is easier to make further adjustments by tuning parameters as opposed to recreating arrays and saving to file each time.

# %%
# # Save train images as 3-dimensional array for further use in model
# with h5py.File('train_dataset.h5', 'w') as hf:
#     hf.create_dataset("train_images",  data=X_train)

# %%
# # Save test images as 3-dimensional array for further use in model
# with h5py.File('test_dataset.h5', 'w') as hf:
#     hf.create_dataset("test_images",  data=X_test)
